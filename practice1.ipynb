# %%
# %pip install konlpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 71.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 41.9 MB/s eta 0:00:00
# ...

# %%
import konlpy

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook
import urllib
import numpy as np

# %%
import os
import sys

# %%
import pickle
import re
import ast
from urllib.request import urlopen
import time

# %%
news_data = []
page_count = 3
client_id = "r3Itf3dVkzTDuMfGDCQt"
client_secret = "1dzuSWNsk1"
encText = urllib.parse.quote("FC서울")
for idx in range(page_count):
    url = "https://openapi.naver.com/v1/search/news.json?query=%EC%A3%BC%EC%8B%9D" + encText + '&start=' + str(idx * 10 + 1) # JSON 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        result = requests.get(response.geturl(), headers = {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret":client_secret})
        news_data.append(result.json())
    else:
        print("Error Code:" + rescode)

# %%
print(len(news_data))
# Out:
# 3

# %%
print(news_data[0])
# Out:
# {'lastBuildDate': 'Mon, 16 Oct 2023 00:09:42 +0900', 'total': 420, 'start': 1, 'display': 10, 'items': [{'title': "'강동원 조카+페르난도 토레스 제자까지 목동에 뜬다!' <b>서울</b> EOU컵 참가선수 ...", 'originallink': 'http://www.osen.co.kr/article/G1112197903', 'link': 'https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629', 'description': '있는 <b>FC서울</b> U18팀 소속 최준영이 출전한다. 이예찬은 한국에서 고교 무대를 누비던 중 재능을 인정받아... 주관, <b>서울</b>특별시, 신한은행, 현대자동차, 아디다스, <b>주식</b>회사 에치와이(hy), 국민체육진흥공단과... ', 'pubDate': 'Fri, 06 Oct 2023 07:47:00 +0900'}, {'title': '[아주경제 코이너스 브리핑] 비트코인, 3400만원대 횡보세…현물 ETF 승인 연...', 'originallink': 'https://www.ajunews.com/view/20230913063540878', 'link': 'https://www.ajunews.com/view/20230913063540878', 'description': "비트코인 현물 ETF 상장이 가능해질 경우 일반 <b>주식</b> 계좌로 비트코인에 투자할 수 있어, 대규모 자금이... ◆롯데정보통신 코튼시드, NFT 기반 '<b>FC서울</b> 팬카드' 2차 판매 롯데정보통신은 NFT 거래소 코튼시드를 통해... ", 'pubDate': 'Wed, 13 Sep 2023 06:40:00 +0900'}, {'title': 'GS건설, 사회공헌활동을 통한 ESG 선도기업으로 도약', 'originallink': 'https://www.viva100.com/main/vi
# ...

# %%
news_data[0]
# Out:
# {'lastBuildDate': 'Mon, 16 Oct 2023 00:09:42 +0900',
#  'total': 420,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': "'강동원 조카+페르난도 토레스 제자까지 목동에 뜬다!' <b>서울</b> EOU컵 참가선수 ...",
#    'originallink': 'http://www.osen.co.kr/article/G1112197903',
#    'link': 'https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629',
#    'description': '있는 <b>FC서울</b> U18팀 소속 최준영이 출전한다. 이예찬은 한국에서 고교 무대를 누비던 중 재능을 인정받아... 주관, <b>서울</b>특별시, 신한은행, 현대자동차, 아디다스, <b>주식</b>회사 에치와이(hy), 국민체육진흥공단과... ',
#    'pubDate': 'Fri, 06 Oct 2023 07:47:00 +0900'},
#   {'title': '[아주경제 코이너스 브리핑] 비트코인, 3400만원대 횡보세…현물 ETF 승인 연...',
#    'originallink': 'https://www.ajunews.com/view/20230913063540878',
#    'link': 'https://www.ajunews.com/view/20230913063540878',
#    'description': "비트코인 현물 ETF 상장이 가능해질 경우 일반 <b>주식</b> 계좌로 비트코인에 투자할 수 있어, 대규모 자금이... ◆롯데정보통신 코튼시드, NFT 기반 '<b>FC서울</b> 팬카드' 2차 판매 롯데정보통신은 NFT 거래소 코튼시드를 통해... ",
#    'pubDate': 'Wed, 13 Sep 2023 06:40:00 +0900'},
# ...

# %%
print(news_data[0]['items'])
# Out:
# [{'title': "'강동원 조카+페르난도 토레스 제자까지 목동에 뜬다!' <b>서울</b> EOU컵 참가선수 ...", 'originallink': 'http://www.osen.co.kr/article/G1112197903', 'link': 'https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629', 'description': '있는 <b>FC서울</b> U18팀 소속 최준영이 출전한다. 이예찬은 한국에서 고교 무대를 누비던 중 재능을 인정받아... 주관, <b>서울</b>특별시, 신한은행, 현대자동차, 아디다스, <b>주식</b>회사 에치와이(hy), 국민체육진흥공단과... ', 'pubDate': 'Fri, 06 Oct 2023 07:47:00 +0900'}, {'title': '[아주경제 코이너스 브리핑] 비트코인, 3400만원대 횡보세…현물 ETF 승인 연...', 'originallink': 'https://www.ajunews.com/view/20230913063540878', 'link': 'https://www.ajunews.com/view/20230913063540878', 'description': "비트코인 현물 ETF 상장이 가능해질 경우 일반 <b>주식</b> 계좌로 비트코인에 투자할 수 있어, 대규모 자금이... ◆롯데정보통신 코튼시드, NFT 기반 '<b>FC서울</b> 팬카드' 2차 판매 롯데정보통신은 NFT 거래소 코튼시드를 통해... ", 'pubDate': 'Wed, 13 Sep 2023 06:40:00 +0900'}, {'title': 'GS건설, 사회공헌활동을 통한 ESG 선도기업으로 도약', 'originallink': 'https://www.viva100.com/main/view.php?key=20230824010007078', 'link': 'https://www.viva100.com/main/view.php?key=20230824010007078', '
# ...

# %%
print(news_data[0]['items'][0])
# Out:
# {'title': "'강동원 조카+페르난도 토레스 제자까지 목동에 뜬다!' <b>서울</b> EOU컵 참가선수 ...", 'originallink': 'http://www.osen.co.kr/article/G1112197903', 'link': 'https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629', 'description': '있는 <b>FC서울</b> U18팀 소속 최준영이 출전한다. 이예찬은 한국에서 고교 무대를 누비던 중 재능을 인정받아... 주관, <b>서울</b>특별시, 신한은행, 현대자동차, 아디다스, <b>주식</b>회사 에치와이(hy), 국민체육진흥공단과... ', 'pubDate': 'Fri, 06 Oct 2023 07:47:00 +0900'}

# %%
print(news_data[0]['items'][0]['link'])
# Out:
# https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629

# %%
print(len(news_data[0]['items']))
# Out:
# 10

# %%
print(news_data[0]['items'][0])
# Out:
# {'title': "'강동원 조카+페르난도 토레스 제자까지 목동에 뜬다!' <b>서울</b> EOU컵 참가선수 ...", 'originallink': 'http://www.osen.co.kr/article/G1112197903', 'link': 'https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629', 'description': '있는 <b>FC서울</b> U18팀 소속 최준영이 출전한다. 이예찬은 한국에서 고교 무대를 누비던 중 재능을 인정받아... 주관, <b>서울</b>특별시, 신한은행, 현대자동차, 아디다스, <b>주식</b>회사 에치와이(hy), 국민체육진흥공단과... ', 'pubDate': 'Fri, 06 Oct 2023 07:47:00 +0900'}

# %%
print(news_data[0]['items'][0]['link'])
# Out:
# https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629

# %%
news_link = []
for page in news_data:
    page_link = []
    for item in page['items']:
        temp_link = item['link']
        if 'naver' in temp_link:
            page_link.append(temp_link)
    news_link.append(page_link)

# %%
for page in news_link:
    for link in page:
        print(link)
# Out:
# https://sports.news.naver.com/news.nhn?oid=109&aid=0004941629
# https://n.news.naver.com/mnews/article/417/0000934564?sid=101
# https://n.news.naver.com/mnews/article/243/0000046832?sid=101
# https://sports.news.naver.com/news.nhn?oid=025&aid=0003289024
# https://sports.news.naver.com/news.nhn?oid=353&aid=0000045214
# https://sports.news.naver.com/news.nhn?oid=216&aid=0000127317
# https://sports.news.naver.com/news.nhn?oid=001&aid=0013920844
# https://n.news.naver.com/mnews/article/079/0003722387?sid=102
# https://n.news.naver.com/mnews/article/015/0004761946?sid=102
# https://n.news.naver.com/mnews/article/050/0000062404?sid=101
# https://n.news.naver.com/mnews/article/025/0003223379?sid=102
# https://sports.news.naver.com/news.nhn?oid=529&aid=0000062947
# https://sports.news.naver.com/news.nhn?oid=529&aid=0000062901
# https://sports.news.naver.com/news.nhn?oid=436&aid=0000055491

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
